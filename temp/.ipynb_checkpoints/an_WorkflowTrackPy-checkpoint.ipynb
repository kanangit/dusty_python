# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

# %%
mpl.rc('figure',  figsize=(10, 10.0*1412.0/520.0))
mpl.rc('image', cmap='gray')

# %%
import pims

# %%
import trackpy as tp

# %%
frames = pims.open(r'g:\My Drive\workAppState\prj_shocks\expData\data20230207\soliton_240fps_73\analysis\20230220histogPython\02_an_WorkflowTrackPy\inputs\*.tif')
frames
# Out:
# <Frames>
# Source: g:\My Drive\workAppState\prj_shocks\expData\data20230207\soliton_240fps_73\analysis\20230220histogPython\02_an_WorkflowTrackPy\inputs\*.tif
# Length: 601 frames
# Frame Shape: (1412, 520)
# Pixel Datatype: uint8

# %%
type(frames)
# Out:
# pims.image_sequence.ImageSequence

# %%
type(frames[0])
# Out:
# pims.frame.Frame

# %%
fig, ax = plt.subplots()
ax = plt.imshow(frames[0])

# %%
f = tp.locate(frames[0], 3)

# %%
tp.annotate(f, frames[0])
# Out:
# <AxesSubplot:>

# %%
f.head(20)
# Out:
#            y           x       mass      size           ecc    signal  \
# 0   0.604938  283.000000   4.471800  0.628539  5.312500e-01  2.705163
# 1   0.678571  368.000000   3.091615  0.566947  1.111111e+00  2.097881
# 2   1.370000  382.820000   5.520741  0.741620  4.727273e-01  2.484333
# 3   1.370370  509.000000   2.981200  0.608581  7.000000e-01  1.877052
# 4   1.887500   52.250000   8.833185  0.602080  2.137931e+00  5.631156
# 5   2.044304   66.943038  17.445541  0.815204  3.238095e-01  5.851985
# 6   2.077670   79.000000   5.686363  0.800485  4.393939e-01  2.042674
# 7   1.642857  122.000000   3.091615  0.597614  8.000000e-01  1.987467
# 8   2.000000  126.698413   3.478067  0.549170  3.315789e+00  2.429126
# 9   2.180328  162.918033  10.102956  0.731792  1.193878e+00  4.692630
# 10  2.166667  177.000000   5.631156  0.747545  2.105263e-01  2.484333
# 11  2.000000  191.977528   4.913459  0.749532  1.780000e+00  2.153089
# 12  2.000000  209.928994   9.330052  0.661717  2.283784e+00  5.244704
# 13  1.935065  250.086580  12.752911  0.686922  4.862385e-01  6.735304
# 14  2.087838  265.898649  16.341393  0.757842  9.411765e-02  6.956133
# 15  1.966387  271.000000  13.139363  0.772424  4.366197e-01  5.299911
# 16  1.809524  321.952381   5.796778  0.774597  1.031746e+00  2.318711
# 17  2.000000  331.395349   4.747837  0.628768  2.529412e+00  2.870785
# 18  2.000000  442.000000   1.821844  0.000000  3.300000e+07  1.821844
# 19  2.195876  501.030928   5.355119  0.799484  9.516129e-01  1.932259
#
#     raw_mass        ep  frame
# 0       11.0 -1.196206      0
# 1       17.0 -1.461784      0
# 2       17.0 -1.461784      0
# 3       18.0 -1.517953      0
# 4       34.0 -3.940655      0
# 5        6.0 -1.038913      0
# 6       50.0  6.611485      0
# 7        4.0 -0.987000      0
# 8       32.0 -3.285237      0
# 9       29.0 -2.629277      0
# 10      28.0 -2.465202      0
# 11      17.0 -1.461784      0
# 12     130.0  0.459488      0
# 13      37.0 -5.623530      0
# 14      24.0 -1.972774      0
# 15      15.0 -1.361058      0
# 16       5.0 -1.012291      0
# 17      18.0 -1.517953      0
# 18      51.0  5.663620      0
# 19       8.0 -1.096591      0

# %%
f = tp.locate(frames[233], 7, minmass = 100, separation = 2, threshold = 5)
tp.annotate(f, frames[233])
# Out:
# <AxesSubplot:>

# %%
f.head()
# Out:
#            y           x        mass      size       ecc     signal  raw_mass  \
# 0  19.769373  202.972325  237.634750  1.616337  0.278902  28.937073     827.0
# 1  28.102941  201.227941  298.139538  1.969996  0.570256  32.444597    1098.0
# 2  30.584288  201.240589  267.887144  1.577771  0.191708  32.444597    1176.0
# 3  32.295977  449.721264  152.577293  1.458231  0.348445  21.045144    1323.0
# 4  34.347341  214.032830  667.744878  1.658065  0.166019  66.204515    3563.0
#
#          ep  frame
# 0  0.082986    233
# 1  0.059071    233
# 2  0.054546    233
# 3  0.047666    233
# 4  0.016312    233

# %%
f.tail()
# Out:
#                 y           x        mass      size       ecc     signal  \
# 1949  1404.030986  200.795775  311.292753  1.286441  0.191362  48.228455
# 1950  1403.674959  478.933665  264.379620  1.252526  0.135903  43.844050
# 1951  1406.465306  413.842857  214.835844  1.284920  0.239128  35.952121
# 1952  1407.238095  214.886905  147.316007  1.136515  0.080724  25.867989
# 1953  1407.377660  293.964539  247.280441  1.291681  0.051480  37.705883
#
#       raw_mass        ep  frame
# 1949     882.0  0.076685    233
# 1950     789.0  0.087980    233
# 1951     620.0  0.120138    233
# 1952     611.0  0.122523    233
# 1953     811.0  0.085018    233

# %%
f_all = tp.batch(frames[:], 7, minmass = 100, separation = 2, threshold = 5)
# Out:
# Frame 600: 1855 features
